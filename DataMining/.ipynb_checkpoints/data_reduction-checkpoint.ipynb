# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv("resources/b5.csv")
data
# Out:
#        E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O1  O2  O3  O4  O5  O6  \
# 0       4   2   5   2   5   1   4   3   5    1  ...   4   1   3   1   5   1
# 1       2   2   3   3   3   3   1   5   1    5  ...   3   3   3   3   2   3
# 2       5   1   1   4   5   1   1   5   5    1  ...   4   5   5   1   5   1
# 3       2   5   2   4   3   4   3   4   4    5  ...   4   3   5   2   4   2
# 4       3   1   3   3   3   1   3   1   3    5  ...   3   1   1   1   3   1
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ..  ..  ..  ..  ..  ..
# 18925   1   4   3   5   4   3   1   2   1    5  ...   1   3   5   3   4   1
# 18926   2   3   2   3   2   3   2   4   4    4  ...   1   2   3   2   3   3
# 18927   2   5   4   5   5   5   1   2   1    5  ...   5   3   1   3   4   1
# 18928   1   4   2   3   2   4   1   3   4    5  ...   3   2   5   3   4   1
# 18929   2   3   1   5   3   3   3   2   2    4  ...   5   1   5   1   4   1
#
#        O7  O8  O9  O10
# 0       4   2   5    5
# 1       3   1   3    2
# 2       5   5   5    5
# 3       5   2   5    5
# 4       3   1   5    3
# ...    ..  ..  ..  ...
# 18925   4   2   5    3
# 18926   4   2   3    3
# 18927   1   5   5    5
# 18928   5   3   5    5
# 18929   5   5   5    5
#
# [18930 rows x 50 columns]

# %% [markdown]
# ### Convert data to numpy array

# %%
X = data.values
X
# Out:
# array([[4, 2, 5, ..., 2, 5, 5],
#        [2, 2, 3, ..., 1, 3, 2],
#        [5, 1, 1, ..., 5, 5, 5],
#        ...,
#        [2, 5, 4, ..., 5, 5, 5],
#        [1, 4, 2, ..., 3, 5, 5],
#        [2, 3, 1, ..., 5, 5, 5]], dtype=int64)

# %% [markdown]
# ### Scale the data

# %%
X = scale(X)
X
# Out:
# array([[ 1.112632  , -0.57855181,  1.28086553, ..., -0.96448433,
#          0.88177594,  1.0099427 ],
#        [-0.51209309, -0.57855181, -0.33817724, ..., -1.76030372,
#         -1.15794039, -2.03840414],
#        [ 1.92499454, -1.34069418, -1.95722   , ...,  1.42297383,
#          0.88177594,  1.0099427 ],
#        ...,
#        [-0.51209309,  1.70787529,  0.47134415, ...,  1.42297383,
#          0.88177594,  1.0099427 ],
#        [-1.32445564,  0.94573292, -1.14769862, ..., -0.16866494,
#          0.88177594,  1.0099427 ],
#        [-0.51209309,  0.18359055, -1.95722   , ...,  1.42297383,
#          0.88177594,  1.0099427 ]])

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### PCA with 50 components

# %%
pca = PCA()
pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [0.16101911 0.09246263 0.07527279 0.07100381 0.05526279 0.0313044
#  0.02660753 0.02099101 0.01937029 0.01849593 0.01794133 0.01735232
#  0.01689316 0.01604282 0.01576013 0.01470117 0.01459846 0.01438242
#  0.01362569 0.01322527 0.0131285  0.01268631 0.01223362 0.01180048
#  0.01164071 0.01136677 0.01108761 0.0106515  0.01045028 0.0102118
#  0.01003675 0.00983507 0.00974897 0.00963948 0.0089566  0.00894
#  0.00868373 0.00840808 0.00831106 0.00808253 0.00793945 0.00760062
#  0.00748126 0.00727417 0.00694749 0.00689884 0.00650197 0.00647554
#  0.0062404  0.00442735]

# %% [markdown]
# ### PCA with 5 components

# %%
pca5 = PCA(n_components=5)
pca5.fit(X)
print(pca5.explained_variance_ratio_)
# Out:
# [0.16101911 0.09246263 0.07527276 0.07100377 0.05526257]

# %% [markdown]
# ### Contributuions of variables to components

# %%
print(pca5.components_)
# Out:
# [[-0.18391014  0.17969564 -0.25064867  0.2061368  -0.23167008  0.1976802
#   -0.22070165  0.13297265 -0.1646324   0.20183617  0.15465885 -0.12978284
#    0.12271811 -0.10236724  0.14227503  0.16681247  0.1627777   0.17394509
#    0.17756882  0.19476315  0.09255979 -0.17766442  0.09908258 -0.11467331
#    0.13341505 -0.05636248  0.18786018 -0.13286202 -0.11972951 -0.18783946
#   -0.11091497  0.05023994 -0.07324244  0.15189875 -0.1087401   0.09267628
#   -0.04455464  0.13905637 -0.0913073  -0.09522001 -0.06943505  0.09889309
#   -0.03539256  0.07185537 -0.13054232  0.08698146 -0.11181571 -0.01241829
#    0.00436534 -0.11687661]
#  [-0.12862187  0.16741212 -0.07309202  0.09547424 -0.14847108  0.12807602
#   -0.1365875   0.10835604 -0.11570091  0.07576808 -0.22728293  0.14366688
#   -0.21599991  0.11922738 -0.18825587 -0.25221019 -0.24452754 -0.24841223
#   -0.19628024 -0.18517723  0.08481653 -0.17630336 -0.05190624 -0.19236417
#    0.17355537 -0.17870151  0.17028722 -0.14026611 -0.2073608  -0.09458076
#    0.12416327 -0.16244296  0.0419519  -0.20154503  0.11325601 -0.16956329
#    0.07219823 -0.11063216  0.0716039   0.05408238 -0.01406042 -0.02883159
#   -0.10895082  0.02695263 -0.02198099  0.06266456  0.03789073 -0.04566897
#   -0.08998066 -0.06995834]
#  [ 0.1547845  -0.14190984  0.06437031 -0.16686202  0.08699671 -0.1031647
#    0.12549628 -0.1908386   0.17683413 -0.15788871 -0.12668646  0.10487416
#   -0.18015518  0.05554437 -0.03570672 -0.08461034 -0.00679652 -0.00971066
#   -0.02360183 -0.06610311  0.14078849 -0.07859956  0.20507225 -0.24969329
#    0.1724709  -0.22641159  0.11283365 -0.18883176 -0.22319533 -0.07480464
#   -0.18949115  0.18291409 -0.18246996  0.14798754 -0.20995116  0.18974474
#   -0.22821815  0.18090159 -0.24093411 -0.17509279  0.03028296 -0.03914264
#    0.02432203 -0.01222326  0.03020013 -0.03343424 -0.01388925  0.06324775
#   -0.12671229  0.0490934 ]
#  [ 0.06421029 -0.07071271  0.11382554 -0.087851    0.06369303  0.03435711
#    0.08308198 -0.04998122  0.01027481 -0.07703363 -0.00724936  0.01092644
#   -0.03036589  0.06487618  0.03469727  0.00503221 -0.04203333 -0.0381114
#   -0.04654198 -0.0890441  -0.00527617  0.05270959 -0.08493065  0.06930386
#   -0.07296974  0.09196919 -0.08045023  0.05107     0.04021822  0.03234464
#   -0.08161942 -0.03826478 -0.16656255 -0.01435794  0.03793209 -0.01482013
#   -0.05537591  0.00593982  0.00371926 -0.14316818 -0.32937782  0.29345966
#   -0.28994099  0.25284448 -0.29771224  0.25762895 -0.26765171 -0.32528895
#   -0.20952689 -0.33018368]
#  [ 0.15045046 -0.12989036  0.06699714 -0.13606134  0.13053024 -0.07234685
#    0.12681812 -0.14185396  0.15558799 -0.11098764  0.14158281 -0.14652885
#    0.10409389  0.00062825  0.12118469  0.15343034  0.16199614  0.16616938
#    0.22673415  0.05032646  0.17818779 -0.109598    0.16646197 -0.20725215
#    0.19368864 -0.14182143  0.15443126 -0.14115551 -0.14266822 -0.02313158
#    0.21221879 -0.1985191   0.11529052 -0.1168424   0.23576697 -0.19483508
#    0.22308287 -0.08989631  0.24849845  0.16710267 -0.01953835  0.11496434
#   -0.0558676   0.15271071  0.06800494  0.07047402  0.02657112  0.00095253
#   -0.0672649   0.00855894]]
